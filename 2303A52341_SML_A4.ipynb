# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankam123niteesh/2303A52341_SML/blob/main/2303A52341_SML_A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ASSIGNMENT-4
# Question 1:
#
# https://www.kaggle.com/datasets/iabhishekofficial/mobile-price-classification?select=train.csvLinks to an external site.
#
# From the above data:
#
# Read the data with pandas and find features and target variables
# Normalize the data with min-max scaling
# Split the data into train and test.

# %%
import pandas as pd
data=pd.read_csv("/content/train.csv")
print(data)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y=data['price_range']
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
x=data.drop('price_range',axis=1)
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
new=data-x.min()/x.max()-x.min()
new
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0        340.749249   0.0     1.533333       0.0   1.0     0.0     4.96875
# 1        519.749249   1.0    -0.166667       1.0   0.0     1.0    50.96875
# 2         61.749249   1.0    -0.166667       1.0   2.0     1.0    38.96875
# 3        113.749249   1.0     1.833333       0.0   0.0     0.0     7.96875
# 4       1319.749249   1.0     0.533333       0.0  13.0     1.0    41.96875
# ...             ...   ...          ...       ...   ...     ...         ...
# 1995     292.749249   1.0    -0.166667       1.0   0.0     1.0    -0.03125
# 1996    1463.749249   1.0     1.933333       1.0   0.0     0.0    36.96875
# 1997    1409.749249   0.0     0.233333       1.0   1.0     1.0    33.96875
# 1998    1010.749249   0.0     0.233333       0.0   4.0     1.0    43.96875
# 1999       8.749249   1.0     1.333333       1.0   5.0     1.0    42.96875
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(new,y,test_size=0.2,random_state=30)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 1572     393.749249   0.0    -0.166667       1.0   6.0     0.0    13.96875
# 1442     471.749249   0.0    -0.166667       1.0   5.0     0.0    50.96875
# 1516     579.749249   1.0     1.233333       1.0  13.0     1.0    39.96875
# 259     1057.749249   1.0     0.933333       1.0   6.0     1.0     3.96875
# 945      330.749249   0.0     0.433333       0.0   0.0     1.0    43.96875
# ...             ...   ...          ...       ...   ...     ...         ...
# 500      776.749249   1.0    -0.166667       1.0   1.0     0.0    51.96875
# 1837     481.749249   0.0    -0.066667       1.0   0.0     1.0    42.96875
# 941      241.749249   0.0    -0.166667       1.0   0.0     1.0    30.96875
# 421      676.749249   0.0     1.533333       1.0   6.0     0.0    54.96875
# 1829     563.749249   0.0     1.033333       1.0   4.0     1.0    45.96875
#
# ...

# %% [markdown]
# Question 2:
#
# Read the data with pandas and describe the data
#
# Find data type and shape of each column
#
# Find the target and features
#
# Find the null values (if yes fill the null values with ‘0’ or mean of that column)
#
# Normalize all the features
#
# Split the data into train and test.

# %%
import pandas as pd
data1=pd.read_csv("/content/sample_data/california_housing_train.csv")
print(data1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
#DESCRIBE
data1.describe()
data1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
#SHAPE
shape=data1.shape
print(shape)
# Out:
# (17000, 9)

# %%
#TYPE
type=data1.dtypes
type
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
#TARGET
Y=data1['median_house_value']
Y
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64

# %%
#FEATURES
X=data1.drop('median_house_value',axis=1)
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income
# ...

# %%
null=data1.isnull()
null
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
normalised=data1-X.min()/X.max()-X.min()
normalised
# Out:
#        households  housing_median_age  latitude  longitude  \
# 0      470.999836           13.980769  0.874315   8.952169
# 1      461.999836           17.980769  1.084315   8.792169
# 2      115.999836           15.980769  0.374315   8.702169
# 3      224.999836           12.980769  0.324315   8.692169
# 4      260.999836           18.980769  0.254315   8.692169
# ...           ...                 ...       ...        ...
# 16995  367.999836           50.980769  7.264315  -0.997831
# 16996  463.999836           34.980769  7.374315  -1.007831
# 16997  454.999836           15.980769  8.524315  -1.037831
# 16998  476.999836           17.980769  8.484315  -1.037831
# 16999  268.999836           50.980769  7.224315  -1.087831
#
#        median_house_value  median_income   population  total_bedrooms  \
# 0                     NaN       0.960374  1011.999916     1281.999845
# 1                     NaN       1.286774  1125.999916     1899.999845
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(normalised,Y,test_size=0.2,random_state=30)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#         households  housing_median_age  latitude  longitude  \
# 7303    295.999836           46.980769  0.674315   4.922169
# 12831   408.999836           17.980769  3.914315   1.452169
# 13976   240.999836           27.980769  4.354315   1.222169
# 3268    550.999836           28.980769  0.414315   5.402169
# 7206    171.999836           45.980769  0.684315   4.932169
# ...            ...                 ...       ...        ...
# 500    1289.999836           18.980769 -0.485685   6.272169
# 12077   169.999836           34.980769  5.864315   1.832169
# 15277   216.999836           50.980769  4.564315   0.982169
# 4517    295.999836           14.980769  0.444315   5.222169
# 5925   1104.999836           45.980769  0.784315   5.052169
#
#        median_house_value  median_income   population  total_bedrooms  \
# 7303                  NaN       4.279274   915.999916      333.999845
# 12831                 NaN       5.784574  1493.999916      425.999845
# ...
